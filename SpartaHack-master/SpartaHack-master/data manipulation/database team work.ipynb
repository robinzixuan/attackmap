# %%
# -*- coding: utf-8 -*-
"""

@author: robin luo
"""
#scrapy the data from CVE data base to the csv form and import it into the PostgreSql to analyze the information



from urllib import request
import re
import psycopg2
conn = psycopg2.connect(database="", user="postgres", password="postgres", host="192.168.10.80", port="5432")
cur = conn.cursor()
cur.execute("CREATE TABLE result(id serial PRIMARY KEY,Name varchar(32),Status varchar(32),Description text,Refer text,Phase text,other text);")
def tablewrite(n,b,c,d,e,f):
    cur.execute("INSERT INTO test(Name,Status,Description,Refer,Phase,other)VALUES(%s, %s, %s, %s, %s, %s)", (n,b,c,d,e,f))
    #crate data basement
D=dict()
list2=[]
file=open("allitems1.txt",'r')
fp=''
f=open('result4.txt',"w")
for line in file:
        list1=line.strip().split()
        if "Name:" in list1:
            a=''
            a=list1[1]
            D[a]=dict()
            list2.append(list1[1])
        else:
            if "======================================================" in list1:
                pass
            elif line=="\n":
                pass
            elif "Status:" in list1:
                D[a]['Status']=list1[1]
            elif "Reference:" in list1:
                if "Reference:" not in D[a]:
                    D[a]["Reference"]=line[11:]
                else:
                    D[a]["Reference"]+="\,"+line[11:]
            else:
                if 'other' not in D[a]:
                    D[a]['other']=line[:-1]
                else:
                    D[a]['other']+="\,"+line[:-1]
file.close()
for n in list2:
    response = request.urlopen(r'http://cve.mitre.org/cgi-bin/cvename.cgi?name='+n) 
    page = response.read()
    page = page.decode('utf-8')    
    page.replace(" ","").replace("\t","").replace("\n", "").strip()
    reg2 = r'<td><b>([\s\S]+?)</b></td>'
    imgre2 = re.compile(reg2)
    imglist2 = re.findall(imgre2, page)
    D[n]['Date Entry Created']=str(imglist2)
    reg3 = r'''Description</th>\s*</tr>\s*\<tr>\s*<td colspan=\"2\"\>([\s\S]+?)\</td>\s*</tr>'''
    imgre3 = re.compile(reg3)
    imglist3 = re.findall(imgre3, page)
    D[n]['Description']=str(imglist3)    
str1="{:<15s},{:<20s},{:<500s},{:100s},{:<500s},{:<500s}".format('Name','Status','Description','Date Entry Created','Reference','other')+'\n'
for n in list2:
   tablewrite(n,D[n]['Status'],D[n]['Description'],D[n]['Reference'],D[n]['Date Entry Created'],D[n]['other'])
   data_str=''
   if 'Status' in D[n]:
            data_str+=",{:<20s}".format(D[n]['Status'])
   else:
            data_str+=",{:<20s}".format(" ")
   if 'Description' in D[n]:
            data_str+=",{:<500s}".format(D[n]['Description'])
   else:
            data_str+=",{:<500s}".format(" ")
   if 'Date Entry Created' in D[n]:
            data_str+=",{:<100s}".format(D[n]['Date Entry Created'])
   else:
            data_str+=",{:<100s}".format(" ") 
   if 'Reference' in D[n]:
            data_str+=",{:<500s}".format(D[n]['Reference'])
   else:
            data_str+=",{:<500s}".format(" ") 
   if 'other' in D[n]:
            data_str+=",{:<500s}".format(D[n]['other'])
   else:
            data_str+=",{:<500s}".format(" ") 
   str1+="{:<15s}".format(n)+data_str+'\n'
 
    
    

fp=str1      
f.write(fp)
file.close()
f.close()

# %%
""""
@author: li
""""
    # scrapy the information from the kaspersky website 
import urllib.request
#import re

page = urllib.request.urlopen('https://cybermap.kaspersky.com/stats/#country=137&type=wav&period=w').read().decode('utf-8')




#page.replace(" ","").replace("\t","").replace("\n", "").strip()
#
#reg = r'<span class="subsystem_description">([\s\S]+?)</span>'
#imgre = re.compile(reg)
#imglist = re.findall(imgre, page)
#print(imglist)
#
#f = open('page.txt','w')
page.replace(" ","").replace("\t","").replace("\n", "").strip()
f.write(page)
#for i in imglist:
#    f.write(i)
f.close()

# %%
# arrey the data to the formula which we want 

l = []

#t = open('allitems.txt','r')

for i in t:
    l.append(i)

t.close()



#x = open('final.txt','w')


for i in range(0,len(l)-1):
    if l[i] == '======================================================\n':
        a=1
        l2 = []
        while l[i+a] != '======================================================\n':
            l2.append(l[i+a])
            a+=1
        i = i+a
        
        x.write(l2[0])
        x.write(l2[1])
        x.write('Reference: \n')
        x.write('URL(Common Vulnerable and Exposures):')
        if l2[2][0:4] == 'URL:':
            x.write(l2[2][4:])
        else:
            x.write('http://cve.mitre.org/cgi-bin/cvename.cgi?name=')
            x.write(l2[0][6:])
        x.write('URL(National Vulnerability Database): ')
        x.write('https://nvd.nist.gov/vuln/detail/')
        x.write(l2[0][6:])
        for m in l2:
            if m[0:10] == 'Reference:':
                x.write(m[10:])
        for o in l2:
            if o[0:10] == 'Reference:' and l2[l2.index(o)+1] == '\n':
                x.write('Description: ')
                b = 1
                while l2[l2.index(o)+1+b] != '\n':
                    x.write(l2[l2.index(o)+1+b])
                    b += 1
                x.write('\n')
        
            

x.close()

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jan 20 15:35:00 2018

@author: admin
"""
#pick up the data which need to support the information which we found
D=dict()
list2=[]
#file=open("2nd part.txt",'r')
for line in file:
        list1=line.strip().split()
        if "Name:" in list1:
            a=''
            a=list1[1]
            D[a]=dict()
            list2.append(list1[1])
        else:
            if "======================================================" in list1:
                pass
            elif line=="\n":
                pass
            else:
                D[a]=line[:-1]
for n in list2:                
    if "INTRUSION" in D[n].upper():
        print(n)
    else:
        pass

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jan 20 18:12:42 2018

@author: admin
"""

D=dict()
list2=[]
list3=[]
pt=input(":")
file=open(pt+".txt",'r')
file1=open("final2.txt",'r')
f=open(pt+'result.txt',"w")
for line in file1:
        list1=line.strip().split()
        if "Name:" in list1:
            a=''
            a=list1[1]
            D[a]=dict()
            list2.append(list1[1])
        else:
            if line=="\n":
                pass
            else:
                if D[a]=={}:
                    D[a]=line[:-1]+"\n"
                else:
                    D[a]+=line[:-1]+"\n"
for line1 in file:
    list3.append(line1.strip())
    list3=sorted(list3)
for n in list3:
    f.write("Name:")
    f.write(n)
    f.write("\n")
    f.write(D[n])
    f.write("\n")
    
f.close()

# %%
#all of input fie data use the # to show
